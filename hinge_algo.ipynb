# %%
LIGHT_IMPORT = True

# If the file is in the current folder:
# %run -i "Calc_Embeddings_Model Training.ipynb"

# quick sanity checks
print("df shape:", df.shape if 'df' in globals() else 'df missing')
print("have get_matches?", 'get_matches' in globals())
# Out:
# shape: (59946, 31)
# WARNING: You are using pip version 22.0.4; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\veera\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# QUERY user 1234 | age 31 | m straight | palo alto, california
# ------------------------------------------------------------------------------------------
# hello! thanks for stopping by! i hope you enjoy yourself!  i am extremely financially responsible and nice! need a new kidney? i'll give you mine! if the doctor won't let us do that, i'll just buy you a new one! no expense is too much for you!  i definitely have skinny genes! rea...
#
# === Matches ===
#
# user 44713 | age 23 | m straight | hayward, california | score=0.594
# hey my name is jacob i'm a die hard raider! lol i work as a massage therapist at chiropractic offices and my personal clients i do some personal tranning generally weight loss, nutrition, and hypertrophy. i'm currently attending ohlone college working on a physical therapy assist...
# ------------------------------------------------------------------------------------------
# user 10612 | age 28 | m gay | san francisco, california | score=0.564
# high energy goofy nerd-jock-goofball type here. often compared to stifler from american pie. im always cracking a joke on someone or something and im a guaranteed good time. i am very easy to get along with once you get to know me. sometimes the high energy may come off like bull...
# ------------------------------------------------------------------------------------------
# user 30903 | age 22 | m straight | novato, california | score=0.560
# first off, i hate the "body type" thing in the details thing bcz there is no in between for jacked and a little extra. i would call myself bulky or buff, or giant maybe. you should like big guys if you think you're interested in me. 6'4" and 255 lbs. just saying. working on getti...
# ------------------------------------------------------------------------------------------
# user 31197 | age 20 | f straight | berkeley, california | score=0.559
# i like to run, lift, dance, box, practice wushu, and olympic lift. i'm a carefree spirit that believes in having fun and enjoying every moment. i fell in love with guatemala summer '11 and went back again december '11. i plan on going back once or twice a year from here on out. n...
# ------------------------------------------------------------------------------------------
# user 23695 | age 21 | m straight | san francisco, california | score=0.559
# oh i suck at these things. uhm. i'm 21 years old living in the best city in the world, san franfuckingcisco. i'm a super easy going person, i try my best to get along with everyone. i'm kind of reserved at first, but once the ice is broken, the fun begins. i hate drama with peopl...
# ------------------------------------------------------------------------------------------
# coords in df: True True
#                           location        lat         lon
# 0  south san francisco, california  37.653540 -122.416866
# 1              oakland, california  37.804456 -122.271356
# 2        san francisco, california  37.779259 -122.419329
# 3             berkeley, california  37.870839 -122.272863
# 4        san francisco, california  37.779259 -122.419329
# coords in tmp: True True
#    user_id        lat         lon
# 0    44713  37.668821 -122.080796
# 1    10612  37.779259 -122.419329
# 2    30903  38.106198 -122.568119
# 3    31197  37.870839 -122.272863
# 4    23695  37.779259 -122.419329
# Base size: 7000
# Unfiltered: 7000 | After location filter (≤50 km): 6044
# Diet| before: 7000 → after: 6223
# Drinks | before: 7000 → after: 7000 (strict=False)
# Smokes | before: 7000 → after: 6731 (strict=False)
# Drugs  | before: 7000 → after: 6152 (strict=True)
# {'base': 7000, 'diet_only': 6223, 'drinks_only': 7000, 'smokes_only': 6731, 'drugs_only': 6152}
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2023
# Unfiltered: 2023 | After location filter (≤50 km): 1717
# After location (≤50 km): 1717
# After age rule: 1342
# Diet| before: 1342 → after: 1152
# After diet: 1152
# Drinks | before: 1152 → after: 1152 (strict=False)
# After drinks (strict=False): 1152
# Smokes | before: 1152 → after: 1117 (strict=False)
# After smokes (strict=False): 1117
# Drugs  | before: 1117 → after: 1008 (strict=True)
# After drugs (strict=True): 1008
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2023
# Unfiltered: 2023 | After location filter (≤50 km): 1717
# After location (≤50 km): 1717
# After age rule: 1342
# Diet| before: 1342 → after: 1152
# After diet: 1152
# Drinks | before: 1152 → after: 1152 (strict=False)
# After drinks (strict=False): 1152
# Smokes | before: 1152 → after: 1117 (strict=False)
# After smokes (strict=False): 1117
# Drugs  | before: 1117 → after: 1008 (strict=True)
# After drugs (strict=True): 1008
# df shape: (59946, 39)
# have get_matches? True

# %%
"""
If any cells in Main Calc Embeddings are wrapped heavy cells those heavy steps 
(e.g., geocoding) will skip during this import.
"""

# %%
import numpy as np
import pandas as pd

# %%
def build_pool(user_id, pool_k=800, max_km=50):
    """
    Make a candidate pool for supervised training:
      - orientation/location/age = hard gates
      - lifestyle = soft (we'll learn its weight)
      - adds essay length as a simple completeness signal
    """
    pool_k = min(pool_k, len(df) - 1)

    #loose pool: let lifestyle through (we'll score it softly)
    cands = get_matches(user_id=user_id, k=pool_k, use_orientation=True, use_location=True, max_km=max_km,use_age=True, 
                        use_diet=False, use_drinks=False, use_smokes=False, use_drugs=False, allow_missing=True).copy()

    # add component scores + distance
    cands = compute_component_scores(user_id=user_id, cands=cands, max_km=max_km,
        drinks_strict=False, smokes_strict=True, drugs_strict=True,allow_missing=True)

     # ensure text_sim present
    if "text_sim" not in cands.columns and "score" in cands.columns:
        cands["text_sim"] = cands["score"]
    cands["text_sim"] = cands["text_sim"].fillna(0)
    
    # Extra simple features
    q_age = int(df.loc[df["user_id"] == user_id, "age"].iloc[0])
    cands["age"] = cands["age"].astype(float)
    cands["age_diff"] = (cands["age"].astype(int) - q_age).abs()
    
    bio = (df.set_index("user_id").loc[cands["user_id"], "bio_text"].fillna("").astype(str))
    cands["essay_len"] = bio.str.len().to_numpy() 

    cands["dist_penalty"] = np.maximum(0.0, cands["distance_km"] - max_km)

    return cands[["user_id","age","sex","orientation","location","text_sim","age_score","age_diff",
                  "lifestyle_score","loc_score","dist_penalty","distance_km","essay_len"]]

# %%
pool = build_pool(user_id=1234, pool_k=800, max_km=50); 
pool.head()
# Out:
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2023
# Unfiltered: 2023 | After location filter (≤50 km): 1717
# After location (≤50 km): 1717
# After age rule: 1342
#     user_id   age sex orientation                   location  text_sim  \
# 13    57256  33.0   f    straight        oakland, california  0.544072
# 16    53843  47.0   f    straight        oakland, california  0.533671
# 18     4015  38.0   f    straight  san francisco, california  0.531963
# 19    30039  24.0   f    straight  san francisco, california  0.531841
# 23    52460  24.0   f    straight    san leandro, california  0.525988
#
#     age_score  age_diff  lifestyle_score  loc_score  dist_penalty  \
# 13        1.0         2             1.00        1.0           0.0
# 16        1.0        16             1.00        1.0           0.0
# 18        1.0         7             1.00        1.0           0.0
# 19        1.0         7             1.00        1.0           0.0
# 23        1.0         7             0.75        1.0           0.0
#
#     distance_km  essay_len
# 13    41.230915       2505
# 16    41.230915       2425
# 18    43.696864       4344
# 19    43.696864       1958
# 23    31.203141       1706

# %%
# Make heuristic labels for "mutual-like"

# 1) Define what counts as a "positive" (tweak thresholds as you like)
POS_THRESH = {
    "text_sim_min": 0.55,       # strong textual affinity
    "lifestyle_min": 0.50,      # lifestyle fairly aligned
    "age_score_min": 1.0,       # mutual half+7 satisfied
    "dist_penalty_max": 0.0,      # not too far (relative to max_km)
}

def is_positive(row, thr=POS_THRESH):
    """Heuristic: mark row as positive if all thresholds pass."""
    return (
        (row.get("text_sim", 0)       >= thr["text_sim_min"]) and
        (row.get("lifestyle_score",0) >= thr["lifestyle_min"]) and
        (row.get("age_score", 0)      >= thr["age_score_min"]) and
        (row.get("dist_penalty", 0)   <= thr["dist_penalty_max"])
    )

def label_pool(pool_df, pos_thresh=POS_THRESH, neg_ratio=3, random_state=42):
    """
    Takes the pool you built earlier for one anchor user.
    pos_thresh = which cutoffs to use.
    neg_ratio=3 = keep at most 3 negatives per positive 
    random_state = seed for reproducible sampling of which negatives to keep.
    """
    df = pool_df.copy().reset_index(drop=True)

    # compute label
    pos_mask = df.apply(is_positive, axis=1, thr=pos_thresh)
    df["y"] = pos_mask.astype(int)
    #Run the is_positive test on every row to get a boolean mask. Make the label column y: 1 for pos, 0 for neg.

    # add a simple explanation for auditing
    def reason(r):
        misses = []
        if r.text_sim        < pos_thresh["text_sim_min"]:    misses.append(f"text<{pos_thresh['text_sim_min']}")
        if r.lifestyle_score < pos_thresh["lifestyle_min"]:    misses.append(f"life<{pos_thresh['lifestyle_min']}")
        if r.age_score       < pos_thresh["age_score_min"]:    misses.append("age_rule=0")
        if r.dist_penalty    > pos_thresh["dist_penalty_max"]: misses.append("dist>R")
        return "POS" if r.y == 1 else ("NEG[" + ",".join(misses) + "]")
    df["label_reason"] = df.apply(reason, axis=1)

    # balance classes: keep all positives; downsample negatives
    rng = np.random.default_rng(random_state) #Make a seeded random generator so selecting neg is reproducible
    pos_idx = df.index[df["y"] == 1].tolist()
    neg_idx = df.index[df["y"] == 0].tolist()

    #Decide how many negatives to keep:At most neg_ratio × (#positives).
    # If there are zero positives, max(1, …) prevents multiplying by zero (keep few neg so the code still works).
    #If there are too many negatives, randomly downsample to target_negs.
    target_negs = min(len(neg_idx), neg_ratio * max(1, len(pos_idx)))
    neg_keep = rng.choice(neg_idx, size=target_negs, replace=False).tolist() if target_negs < len(neg_idx) else neg_idx
    keep_idx = set(pos_idx) | set(neg_keep)
    labeled = df.loc[sorted(keep_idx)].reset_index(drop=True)
    #Keep all positives + the sampled negatives. Sort indices and reset to a tidy 0..M-1 index.

    # clean up
    if "distance_km" in labeled.columns:
        labeled["distance_km"] = labeled["distance_km"].replace([np.inf, -np.inf], np.nan)
        labeled["distance_km"] = labeled["distance_km"].fillna(labeled["distance_km"].max()).clip(lower=0)

    return labeled

# 2) Build a multi-user training set in one go
def build_training_set(anchor_user_ids, pool_k=400, max_km=50,
                       pos_thresh=POS_THRESH, neg_ratio=3, random_state=42):
    """
    For each anchor user, build a pool (loose lifestyle gates), label it, and stack.
    Returns a single DataFrame with columns:
      anchor_user, candidate_user(=user_id), features..., y, label_reason
    """
    rows = []
    for u in anchor_user_ids:
        pool = build_pool(user_id=u, pool_k=pool_k, max_km=max_km)
        lab  = label_pool(pool, pos_thresh=pos_thresh, neg_ratio=neg_ratio, random_state=random_state)
        lab = lab.rename(columns={"user_id": "candidate_user"})
        lab.insert(0, "anchor_user", u)
        rows.append(lab)
    out = pd.concat(rows, ignore_index=True) if rows else pd.DataFrame()
    return out

# 3) 
pool = build_pool(user_id=10, pool_k=5000, max_km=50)
labeled = label_pool(pool, POS_THRESH, neg_ratio=3)
labeled["y"].value_counts(), labeled.head()
# Out:
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2206
# Unfiltered: 2206 | After location filter (≤50 km): 2186
# After location (≤50 km): 2186
# After age rule: 1872
# (y
#  0    1349
#  1     523
#  Name: count, dtype: int64,
#     user_id   age sex orientation                   location  text_sim  \
#  0    37350  52.0   f    straight   redwood city, california  0.718680
#  1    26930  25.0   f    straight     menlo park, california  0.694204
#  2    36162  44.0   f    straight       martinez, california  0.671570
#  3    49065  25.0   f    straight       pacifica, california  0.664452
#  4    52547  25.0   f    straight  san francisco, california  0.661309
#
#     age_score  age_diff  lifestyle_score  loc_score  dist_penalty  distance_km  \
#  0        1.0        17         0.666667        1.0           0.0    36.491073
#  1        1.0        10         0.666667        1.0           0.0    42.146441
#  2        1.0         9         1.000000        1.0           0.0    36.167769
#  3        1.0        10         0.666667        1.0           0.0    21.350781
#  4        1.0        10         0.500000        1.0           0.0     0.000000
#
#     essay_len  y label_reason
#  0       1550  1          POS
#  1       1348  1          POS
#  2        813  1          POS
#  3       5327  1          POS
#  4       3783  1          POS  )

# %%
# === Train Hinge-style logistic baseline (flat-inside-radius) ===
from sklearn.model_selection import GroupKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

# 1) choose anchor users (bio + coords)
has_bio    = df["bio_text"].fillna("").astype(str).str.len() > 50
has_coords = df["lat"].notna() & df["lon"].notna()
anchor_pool = df.loc[has_bio & has_coords, "user_id"].astype(int).tolist()

rng = np.random.default_rng(42)
N_ANCHORS = min(300, len(anchor_pool))
anchor_user_ids = rng.choice(anchor_pool, size=N_ANCHORS, replace=False).tolist()

# 2) build labeled dataset
MAX_KM = 50
train_df = build_training_set(
    anchor_user_ids=anchor_user_ids,
    pool_k=400, max_km=MAX_KM,
    pos_thresh=POS_THRESH, neg_ratio=3, random_state=42
).copy()

# 3) features/target/groups (NO raw distance/loc; use dist_penalty)
X_cols = ["text_sim", "lifestyle_score", "age_diff", "essay_len", "dist_penalty"]

X = train_df[X_cols].copy()
if "dist_penalty" not in X.columns and "distance_km" in train_df.columns:
    X["dist_penalty"] = np.maximum(0.0, train_df["distance_km"] - MAX_KM)
X["essay_len"]    = X["essay_len"].fillna(0).clip(lower=0)
X["dist_penalty"] = X["dist_penalty"].fillna(0).clip(lower=0)

y = train_df["y"].astype(int).values
groups = train_df["anchor_user"].values

# 4) pipeline (scaler + LR) + grouped CV
pipe = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=300, C=0.8, class_weight="balanced", solver="lbfgs")
)
cv = GroupKFold(n_splits=5)
roc = cross_val_score(pipe, X, y, groups=groups, cv=cv, scoring="roc_auc")
pr  = cross_val_score(pipe, X, y, groups=groups, cv=cv, scoring="average_precision")
print(f"AUC-ROC: {roc.mean():.3f} ± {roc.std():.3f} | PR-AUC: {pr.mean():.3f} ± {pr.std():.3f}")

# 5) fit final model on ALL data
pipe.fit(X, y)
scaler = pipe.named_steps["standardscaler"]
clf    = pipe.named_steps["logisticregression"]

# 6) Inspect learned weights (standardized)
coef = pd.Series(clf.coef_[0], index=X_cols).sort_values(ascending=False)
display(coef.to_frame("coef (standardized)"))
display(coef.sort_values().to_frame("coef (standardized)").head(5))  # most negative

# 7) package for inference
hinge_model = {"clf": clf, "scaler": scaler, "X_cols": X_cols, "params": {"max_km": MAX_KM}}
# Out:
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2024
# Unfiltered: 2024 | After location filter (≤50 km): 1873
# After location (≤50 km): 1873
# After age rule: 1502
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2708
# Unfiltered: 2708 | After location filter (≤50 km): 2670
# After location (≤50 km): 2670
# After age rule: 2434
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1497
# Unfiltered: 1497 | After location filter (≤50 km): 1486
# After location (≤50 km): 1486
# After age rule: 1091
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2053
# Unfiltered: 2053 | After location filter (≤50 km): 2035
# After location (≤50 km): 2035
# After age rule: 813
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1986
# Unfiltered: 1986 | After location filter (≤50 km): 1799
# After location (≤50 km): 1799
# After age rule: 1076
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2045
# Unfiltered: 2045 | After location filter (≤50 km): 2040
# After location (≤50 km): 2040
# After age rule: 1485
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2199
# Unfiltered: 2199 | After location filter (≤50 km): 2185
# After location (≤50 km): 2185
# After age rule: 1963
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1640
# Unfiltered: 1640 | After location filter (≤50 km): 1630
# After location (≤50 km): 1630
# After age rule: 1014
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1757
# Unfiltered: 1757 | After location filter (≤50 km): 1740
# After location (≤50 km): 1740
# After age rule: 1516
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1802
# Unfiltered: 1802 | After location filter (≤50 km): 1779
# After location (≤50 km): 1779
# After age rule: 1324
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2525
# Unfiltered: 2525 | After location filter (≤50 km): 2325
# After location (≤50 km): 2325
# After age rule: 1791
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1985
# Unfiltered: 1985 | After location filter (≤50 km): 1971
# After location (≤50 km): 1971
# After age rule: 1528
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1936
# Unfiltered: 1936 | After location filter (≤50 km): 1924
# After location (≤50 km): 1924
# After age rule: 1587
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1794
# Unfiltered: 1794 | After location filter (≤50 km): 1778
# After location (≤50 km): 1778
# After age rule: 1596
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2153
# Unfiltered: 2153 | After location filter (≤50 km): 1814
# After location (≤50 km): 1814
# After age rule: 1443
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2370
# Unfiltered: 2370 | After location filter (≤50 km): 2363
# After location (≤50 km): 2363
# After age rule: 1157
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2132
# Unfiltered: 2132 | After location filter (≤50 km): 1866
# After location (≤50 km): 1866
# After age rule: 300
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1972
# Unfiltered: 1972 | After location filter (≤50 km): 1713
# After location (≤50 km): 1713
# After age rule: 1319
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1947
# Unfiltered: 1947 | After location filter (≤50 km): 1944
# After location (≤50 km): 1944
# After age rule: 1333
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1759
# Unfiltered: 1759 | After location filter (≤50 km): 1751
# After location (≤50 km): 1751
# After age rule: 1423
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2690
# Unfiltered: 2690 | After location filter (≤50 km): 2655
# After location (≤50 km): 2655
# After age rule: 899
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2429
# Unfiltered: 2429 | After location filter (≤50 km): 2388
# After location (≤50 km): 2388
# After age rule: 2261
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1818
# Unfiltered: 1818 | After location filter (≤50 km): 1813
# After location (≤50 km): 1813
# After age rule: 1275
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2100
# Unfiltered: 2100 | After location filter (≤50 km): 2083
# After location (≤50 km): 2083
# After age rule: 1417
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2088
# Unfiltered: 2088 | After location filter (≤50 km): 1895
# After location (≤50 km): 1895
# After age rule: 1710
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1696
# Unfiltered: 1696 | After location filter (≤50 km): 1581
# After location (≤50 km): 1581
# After age rule: 1084
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2577
# Unfiltered: 2577 | After location filter (≤50 km): 2539
# After location (≤50 km): 2539
# After age rule: 446
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2648
# Unfiltered: 2648 | After location filter (≤50 km): 2615
# After location (≤50 km): 2615
# After age rule: 1493
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2089
# Unfiltered: 2089 | After location filter (≤50 km): 2067
# After location (≤50 km): 2067
# After age rule: 1445
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2341
# Unfiltered: 2341 | After location filter (≤50 km): 2312
# After location (≤50 km): 2312
# After age rule: 2049
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2220
# Unfiltered: 2220 | After location filter (≤50 km): 2207
# After location (≤50 km): 2207
# After age rule: 419
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2650
# Unfiltered: 2650 | After location filter (≤50 km): 2622
# After location (≤50 km): 2622
# After age rule: 2368
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2401
# Unfiltered: 2401 | After location filter (≤50 km): 2375
# After location (≤50 km): 2375
# After age rule: 1683
# Start pool: 5000 (max_candidates=5000)
# After orientation: 419
# Unfiltered: 419 | After location filter (≤50 km): 417
# After location (≤50 km): 417
# After age rule: 193
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1795
# Unfiltered: 1795 | After location filter (≤50 km): 1780
# After location (≤50 km): 1780
# After age rule: 1402
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2174
# Unfiltered: 2174 | After location filter (≤50 km): 1878
# After location (≤50 km): 1878
# After age rule: 1223
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2463
# Unfiltered: 2463 | After location filter (≤50 km): 2455
# After location (≤50 km): 2455
# After age rule: 1818
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1787
# Unfiltered: 1787 | After location filter (≤50 km): 1623
# After location (≤50 km): 1623
# After age rule: 981
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1978
# Unfiltered: 1978 | After location filter (≤50 km): 1972
# After location (≤50 km): 1972
# After age rule: 1394
# Start pool: 5000 (max_candidates=5000)
# After orientation: 362
# Unfiltered: 362 | After location filter (≤50 km): 361
# After location (≤50 km): 361
# After age rule: 326
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1892
# Unfiltered: 1892 | After location filter (≤50 km): 1878
# After location (≤50 km): 1878
# After age rule: 897
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1766
# Unfiltered: 1766 | After location filter (≤50 km): 1636
# After location (≤50 km): 1636
# After age rule: 1334
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1970
# Unfiltered: 1970 | After location filter (≤50 km): 1896
# After location (≤50 km): 1896
# After age rule: 871
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2003
# Unfiltered: 2003 | After location filter (≤50 km): 1986
# After location (≤50 km): 1986
# After age rule: 1437
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2028
# Unfiltered: 2028 | After location filter (≤50 km): 1999
# After location (≤50 km): 1999
# After age rule: 1733
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2304
# Unfiltered: 2304 | After location filter (≤50 km): 2017
# After location (≤50 km): 2017
# After age rule: 888
# Start pool: 5000 (max_candidates=5000)
# After orientation: 367
# Unfiltered: 367 | After location filter (≤50 km): 364
# After location (≤50 km): 364
# After age rule: 262
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1841
# Unfiltered: 1841 | After location filter (≤50 km): 1827
# After location (≤50 km): 1827
# After age rule: 1668
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1796
# Unfiltered: 1796 | After location filter (≤50 km): 1794
# After location (≤50 km): 1794
# After age rule: 662
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2081
# Unfiltered: 2081 | After location filter (≤50 km): 1905
# After location (≤50 km): 1905
# After age rule: 1484
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2435
# Unfiltered: 2435 | After location filter (≤50 km): 2167
# After location (≤50 km): 2167
# After age rule: 1679
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2208
# Unfiltered: 2208 | After location filter (≤50 km): 2191
# After location (≤50 km): 2191
# After age rule: 1669
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2287
# Unfiltered: 2287 | After location filter (≤50 km): 1946
# After location (≤50 km): 1946
# After age rule: 952
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2612
# Unfiltered: 2612 | After location filter (≤50 km): 2579
# After location (≤50 km): 2579
# After age rule: 1397
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2031
# Unfiltered: 2031 | After location filter (≤50 km): 2027
# After location (≤50 km): 2027
# After age rule: 1455
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2394
# Unfiltered: 2394 | After location filter (≤50 km): 2386
# After location (≤50 km): 2386
# After age rule: 2035
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2022
# Unfiltered: 2022 | After location filter (≤50 km): 1845
# After location (≤50 km): 1845
# After age rule: 1588
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2364
# Unfiltered: 2364 | After location filter (≤50 km): 2345
# After location (≤50 km): 2345
# After age rule: 1584
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2183
# Unfiltered: 2183 | After location filter (≤50 km): 2178
# After location (≤50 km): 2178
# After age rule: 816
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2433
# Unfiltered: 2433 | After location filter (≤50 km): 2194
# After location (≤50 km): 2194
# After age rule: 2029
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1659
# Unfiltered: 1659 | After location filter (≤50 km): 1653
# After location (≤50 km): 1653
# After age rule: 1390
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2208
# Unfiltered: 2208 | After location filter (≤50 km): 1986
# After location (≤50 km): 1986
# After age rule: 1682
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2210
# Unfiltered: 2210 | After location filter (≤50 km): 1859
# After location (≤50 km): 1859
# After age rule: 1628
# Start pool: 5000 (max_candidates=5000)
# After orientation: 452
# Unfiltered: 452 | After location filter (≤50 km): 451
# After location (≤50 km): 451
# After age rule: 210
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2412
# Unfiltered: 2412 | After location filter (≤50 km): 2085
# After location (≤50 km): 2085
# After age rule: 1767
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2509
# Unfiltered: 2509 | After location filter (≤50 km): 2489
# After location (≤50 km): 2489
# After age rule: 2092
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1664
# Unfiltered: 1664 | After location filter (≤50 km): 1652
# After location (≤50 km): 1652
# After age rule: 713
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1622
# Unfiltered: 1622 | After location filter (≤50 km): 1617
# After location (≤50 km): 1617
# After age rule: 1445
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2201
# Unfiltered: 2201 | After location filter (≤50 km): 2113
# After location (≤50 km): 2113
# After age rule: 1002
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2360
# Unfiltered: 2360 | After location filter (≤50 km): 2355
# After location (≤50 km): 2355
# After age rule: 2105
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2370
# Unfiltered: 2370 | After location filter (≤50 km): 2346
# After location (≤50 km): 2346
# After age rule: 1828
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2384
# Unfiltered: 2384 | After location filter (≤50 km): 2317
# After location (≤50 km): 2317
# After age rule: 1351
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1788
# Unfiltered: 1788 | After location filter (≤50 km): 1759
# After location (≤50 km): 1759
# After age rule: 1479
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2111
# Unfiltered: 2111 | After location filter (≤50 km): 1815
# After location (≤50 km): 1815
# After age rule: 1388
# Start pool: 5000 (max_candidates=5000)
# After orientation: 595
# Unfiltered: 595 | After location filter (≤50 km): 595
# After location (≤50 km): 595
# After age rule: 274
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2577
# Unfiltered: 2577 | After location filter (≤50 km): 2542
# After location (≤50 km): 2542
# After age rule: 1433
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1847
# Unfiltered: 1847 | After location filter (≤50 km): 1736
# After location (≤50 km): 1736
# After age rule: 1262
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1861
# Unfiltered: 1861 | After location filter (≤50 km): 1851
# After location (≤50 km): 1851
# After age rule: 1554
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1684
# Unfiltered: 1684 | After location filter (≤50 km): 1679
# After location (≤50 km): 1679
# After age rule: 1348
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1898
# Unfiltered: 1898 | After location filter (≤50 km): 1885
# After location (≤50 km): 1885
# After age rule: 1423
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2097
# Unfiltered: 2097 | After location filter (≤50 km): 2090
# After location (≤50 km): 2090
# After age rule: 1757
# Start pool: 5000 (max_candidates=5000)
# After orientation: 485
# Unfiltered: 485 | After location filter (≤50 km): 482
# After location (≤50 km): 482
# After age rule: 284
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2164
# Unfiltered: 2164 | After location filter (≤50 km): 1978
# After location (≤50 km): 1978
# After age rule: 1770
# Start pool: 5000 (max_candidates=5000)
# After orientation: 363
# Unfiltered: 363 | After location filter (≤50 km): 362
# After location (≤50 km): 362
# After age rule: 259
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2074
# Unfiltered: 2074 | After location filter (≤50 km): 1849
# After location (≤50 km): 1849
# After age rule: 1555
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2309
# Unfiltered: 2309 | After location filter (≤50 km): 2298
# After location (≤50 km): 2298
# After age rule: 1985
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1901
# Unfiltered: 1901 | After location filter (≤50 km): 1663
# After location (≤50 km): 1663
# After age rule: 1284
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1849
# Unfiltered: 1849 | After location filter (≤50 km): 1827
# After location (≤50 km): 1827
# After age rule: 1490
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2142
# Unfiltered: 2142 | After location filter (≤50 km): 2115
# After location (≤50 km): 2115
# After age rule: 1382
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2135
# Unfiltered: 2135 | After location filter (≤50 km): 2117
# After location (≤50 km): 2117
# After age rule: 1765
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1641
# Unfiltered: 1641 | After location filter (≤50 km): 1436
# After location (≤50 km): 1436
# After age rule: 845
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1283
# Unfiltered: 1283 | After location filter (≤50 km): 1273
# After location (≤50 km): 1273
# After age rule: 786
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2372
# Unfiltered: 2372 | After location filter (≤50 km): 2348
# After location (≤50 km): 2348
# After age rule: 2111
# Start pool: 5000 (max_candidates=5000)
# After orientation: 3086
# Unfiltered: 3086 | After location filter (≤50 km): 931
# After location (≤50 km): 931
# After age rule: 656
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2230
# Unfiltered: 2230 | After location filter (≤50 km): 2221
# After location (≤50 km): 2221
# After age rule: 1986
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1633
# Unfiltered: 1633 | After location filter (≤50 km): 1614
# After location (≤50 km): 1614
# After age rule: 1297
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2816
# Unfiltered: 2816 | After location filter (≤50 km): 2513
# After location (≤50 km): 2513
# After age rule: 1976
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2408
# Unfiltered: 2408 | After location filter (≤50 km): 2116
# After location (≤50 km): 2116
# After age rule: 1514
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1870
# Unfiltered: 1870 | After location filter (≤50 km): 1851
# After location (≤50 km): 1851
# After age rule: 1415
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2173
# Unfiltered: 2173 | After location filter (≤50 km): 2154
# After location (≤50 km): 2154
# After age rule: 1846
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1990
# Unfiltered: 1990 | After location filter (≤50 km): 1974
# After location (≤50 km): 1974
# After age rule: 1646
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2024
# Unfiltered: 2024 | After location filter (≤50 km): 2011
# After location (≤50 km): 2011
# After age rule: 1606
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2009
# Unfiltered: 2009 | After location filter (≤50 km): 2005
# After location (≤50 km): 2005
# After age rule: 1153
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2268
# Unfiltered: 2268 | After location filter (≤50 km): 1953
# After location (≤50 km): 1953
# After age rule: 894
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2666
# Unfiltered: 2666 | After location filter (≤50 km): 2638
# After location (≤50 km): 2638
# After age rule: 2276
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1796
# Unfiltered: 1796 | After location filter (≤50 km): 1792
# After location (≤50 km): 1792
# After age rule: 779
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2058
# Unfiltered: 2058 | After location filter (≤50 km): 2047
# After location (≤50 km): 2047
# After age rule: 1417
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1517
# Unfiltered: 1517 | After location filter (≤50 km): 1511
# After location (≤50 km): 1511
# After age rule: 1340
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2591
# Unfiltered: 2591 | After location filter (≤50 km): 2565
# After location (≤50 km): 2565
# After age rule: 2186
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2223
# Unfiltered: 2223 | After location filter (≤50 km): 2205
# After location (≤50 km): 2205
# After age rule: 1987
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2290
# Unfiltered: 2290 | After location filter (≤50 km): 2276
# After location (≤50 km): 2276
# After age rule: 2036
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1544
# Unfiltered: 1544 | After location filter (≤50 km): 1457
# After location (≤50 km): 1457
# After age rule: 894
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2074
# Unfiltered: 2074 | After location filter (≤50 km): 2066
# After location (≤50 km): 2066
# After age rule: 1786
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1454
# Unfiltered: 1454 | After location filter (≤50 km): 1243
# After location (≤50 km): 1243
# After age rule: 929
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2161
# Unfiltered: 2161 | After location filter (≤50 km): 2154
# After location (≤50 km): 2154
# After age rule: 1973
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2526
# Unfiltered: 2526 | After location filter (≤50 km): 2497
# After location (≤50 km): 2497
# After age rule: 2045
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2035
# Unfiltered: 2035 | After location filter (≤50 km): 2020
# After location (≤50 km): 2020
# After age rule: 1382
# Start pool: 5000 (max_candidates=5000)
# After orientation: 356
# Unfiltered: 356 | After location filter (≤50 km): 354
# After location (≤50 km): 354
# After age rule: 184
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2058
# Unfiltered: 2058 | After location filter (≤50 km): 2053
# After location (≤50 km): 2053
# After age rule: 1567
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1955
# Unfiltered: 1955 | After location filter (≤50 km): 1782
# After location (≤50 km): 1782
# After age rule: 1104
# Start pool: 5000 (max_candidates=5000)
# After orientation: 355
# Unfiltered: 355 | After location filter (≤50 km): 354
# After location (≤50 km): 354
# After age rule: 306
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2197
# Unfiltered: 2197 | After location filter (≤50 km): 2178
# After location (≤50 km): 2178
# After age rule: 1851
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1904
# Unfiltered: 1904 | After location filter (≤50 km): 1891
# After location (≤50 km): 1891
# After age rule: 1464
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2378
# Unfiltered: 2378 | After location filter (≤50 km): 2356
# After location (≤50 km): 2356
# After age rule: 2184
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2037
# Unfiltered: 2037 | After location filter (≤50 km): 1794
# After location (≤50 km): 1794
# After age rule: 1524
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2104
# Unfiltered: 2104 | After location filter (≤50 km): 2097
# After location (≤50 km): 2097
# After age rule: 1613
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2187
# Unfiltered: 2187 | After location filter (≤50 km): 2116
# After location (≤50 km): 2116
# After age rule: 1679
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1804
# Unfiltered: 1804 | After location filter (≤50 km): 179
# After location (≤50 km): 179
# After age rule: 152
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1852
# Unfiltered: 1852 | After location filter (≤50 km): 1825
# After location (≤50 km): 1825
# After age rule: 920
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2722
# Unfiltered: 2722 | After location filter (≤50 km): 2686
# After location (≤50 km): 2686
# After age rule: 1265
# Start pool: 5000 (max_candidates=5000)
# After orientation: 503
# Unfiltered: 503 | After location filter (≤50 km): 468
# After location (≤50 km): 468
# After age rule: 281
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1991
# Unfiltered: 1991 | After location filter (≤50 km): 1894
# After location (≤50 km): 1894
# After age rule: 1092
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2010
# Unfiltered: 2010 | After location filter (≤50 km): 1996
# After location (≤50 km): 1996
# After age rule: 1175
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2035
# Unfiltered: 2035 | After location filter (≤50 km): 2021
# After location (≤50 km): 2021
# After age rule: 1592
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2193
# Unfiltered: 2193 | After location filter (≤50 km): 2168
# After location (≤50 km): 2168
# After age rule: 1126
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1713
# Unfiltered: 1713 | After location filter (≤50 km): 1705
# After location (≤50 km): 1705
# After age rule: 1251
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1933
# Unfiltered: 1933 | After location filter (≤50 km): 1929
# After location (≤50 km): 1929
# After age rule: 1622
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2447
# Unfiltered: 2447 | After location filter (≤50 km): 2428
# After location (≤50 km): 2428
# After age rule: 2045
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1925
# Unfiltered: 1925 | After location filter (≤50 km): 1646
# After location (≤50 km): 1646
# After age rule: 1241
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2131
# Unfiltered: 2131 | After location filter (≤50 km): 1922
# After location (≤50 km): 1922
# After age rule: 1447
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2299
# Unfiltered: 2299 | After location filter (≤50 km): 2282
# After location (≤50 km): 2282
# After age rule: 474
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2676
# Unfiltered: 2676 | After location filter (≤50 km): 2650
# After location (≤50 km): 2650
# After age rule: 2337
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2223
# Unfiltered: 2223 | After location filter (≤50 km): 1936
# After location (≤50 km): 1936
# After age rule: 1558
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2348
# Unfiltered: 2348 | After location filter (≤50 km): 2338
# After location (≤50 km): 2338
# After age rule: 1049
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2155
# Unfiltered: 2155 | After location filter (≤50 km): 1947
# After location (≤50 km): 1947
# After age rule: 1592
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2638
# Unfiltered: 2638 | After location filter (≤50 km): 2419
# After location (≤50 km): 2419
# After age rule: 2084
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1909
# Unfiltered: 1909 | After location filter (≤50 km): 1900
# After location (≤50 km): 1900
# After age rule: 1501
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2538
# Unfiltered: 2538 | After location filter (≤50 km): 2316
# After location (≤50 km): 2316
# After age rule: 2056
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2433
# Unfiltered: 2433 | After location filter (≤50 km): 2412
# After location (≤50 km): 2412
# After age rule: 2143
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1487
# Unfiltered: 1487 | After location filter (≤50 km): 1482
# After location (≤50 km): 1482
# After age rule: 1144
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1752
# Unfiltered: 1752 | After location filter (≤50 km): 1611
# After location (≤50 km): 1611
# After age rule: 1417
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2282
# Unfiltered: 2282 | After location filter (≤50 km): 2259
# After location (≤50 km): 2259
# After age rule: 1754
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1993
# Unfiltered: 1993 | After location filter (≤50 km): 1981
# After location (≤50 km): 1981
# After age rule: 1613
# Start pool: 5000 (max_candidates=5000)
# After orientation: 422
# Unfiltered: 422 | After location filter (≤50 km): 422
# After location (≤50 km): 422
# After age rule: 389
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1874
# Unfiltered: 1874 | After location filter (≤50 km): 1862
# After location (≤50 km): 1862
# After age rule: 1377
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2017
# Unfiltered: 2017 | After location filter (≤50 km): 2005
# After location (≤50 km): 2005
# After age rule: 1306
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1994
# Unfiltered: 1994 | After location filter (≤50 km): 1973
# After location (≤50 km): 1973
# After age rule: 1531
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2039
# Unfiltered: 2039 | After location filter (≤50 km): 2030
# After location (≤50 km): 2030
# After age rule: 1705
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2258
# Unfiltered: 2258 | After location filter (≤50 km): 2233
# After location (≤50 km): 2233
# After age rule: 2016
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2124
# Unfiltered: 2124 | After location filter (≤50 km): 1869
# After location (≤50 km): 1869
# After age rule: 1274
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2234
# Unfiltered: 2234 | After location filter (≤50 km): 2227
# After location (≤50 km): 2227
# After age rule: 2037
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2168
# Unfiltered: 2168 | After location filter (≤50 km): 2147
# After location (≤50 km): 2147
# After age rule: 1656
# Start pool: 5000 (max_candidates=5000)
# After orientation: 389
# Unfiltered: 389 | After location filter (≤50 km): 386
# After location (≤50 km): 386
# After age rule: 304
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2286
# Unfiltered: 2286 | After location filter (≤50 km): 2260
# After location (≤50 km): 2260
# After age rule: 1840
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2472
# Unfiltered: 2472 | After location filter (≤50 km): 2443
# After location (≤50 km): 2443
# After age rule: 1703
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2205
# Unfiltered: 2205 | After location filter (≤50 km): 2190
# After location (≤50 km): 2190
# After age rule: 1019
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2112
# Unfiltered: 2112 | After location filter (≤50 km): 1823
# After location (≤50 km): 1823
# After age rule: 379
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1948
# Unfiltered: 1948 | After location filter (≤50 km): 1945
# After location (≤50 km): 1945
# After age rule: 1740
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2574
# Unfiltered: 2574 | After location filter (≤50 km): 2525
# After location (≤50 km): 2525
# After age rule: 1072
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2358
# Unfiltered: 2358 | After location filter (≤50 km): 2336
# After location (≤50 km): 2336
# After age rule: 697
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2072
# Unfiltered: 2072 | After location filter (≤50 km): 2046
# After location (≤50 km): 2046
# After age rule: 1589
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1517
# Unfiltered: 1517 | After location filter (≤50 km): 462
# After location (≤50 km): 462
# After age rule: 339
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1715
# Unfiltered: 1715 | After location filter (≤50 km): 1702
# After location (≤50 km): 1702
# After age rule: 1403
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1912
# Unfiltered: 1912 | After location filter (≤50 km): 1910
# After location (≤50 km): 1910
# After age rule: 1772
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1871
# Unfiltered: 1871 | After location filter (≤50 km): 1846
# After location (≤50 km): 1846
# After age rule: 1437
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2280
# Unfiltered: 2280 | After location filter (≤50 km): 2258
# After location (≤50 km): 2258
# After age rule: 1510
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2096
# Unfiltered: 2096 | After location filter (≤50 km): 2080
# After location (≤50 km): 2080
# After age rule: 1608
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2814
# Unfiltered: 2814 | After location filter (≤50 km): 2804
# After location (≤50 km): 2804
# After age rule: 2410
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1711
# Unfiltered: 1711 | After location filter (≤50 km): 1549
# After location (≤50 km): 1549
# After age rule: 426
# Start pool: 5000 (max_candidates=5000)
# After orientation: 330
# Unfiltered: 330 | After location filter (≤50 km): 328
# After location (≤50 km): 328
# After age rule: 256
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2199
# Unfiltered: 2199 | After location filter (≤50 km): 2180
# After location (≤50 km): 2180
# After age rule: 1948
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1810
# Unfiltered: 1810 | After location filter (≤50 km): 1473
# After location (≤50 km): 1473
# After age rule: 754
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2216
# Unfiltered: 2216 | After location filter (≤50 km): 1890
# After location (≤50 km): 1890
# After age rule: 1557
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1838
# Unfiltered: 1838 | After location filter (≤50 km): 1833
# After location (≤50 km): 1833
# After age rule: 1217
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1923
# Unfiltered: 1923 | After location filter (≤50 km): 1883
# After location (≤50 km): 1883
# After age rule: 1490
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2216
# Unfiltered: 2216 | After location filter (≤50 km): 2199
# After location (≤50 km): 2199
# After age rule: 1373
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2077
# Unfiltered: 2077 | After location filter (≤50 km): 2062
# After location (≤50 km): 2062
# After age rule: 1868
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2042
# Unfiltered: 2042 | After location filter (≤50 km): 2017
# After location (≤50 km): 2017
# After age rule: 1462
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1741
# Unfiltered: 1741 | After location filter (≤50 km): 1733
# After location (≤50 km): 1733
# After age rule: 1542
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2334
# Unfiltered: 2334 | After location filter (≤50 km): 2278
# After location (≤50 km): 2278
# After age rule: 1962
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2270
# Unfiltered: 2270 | After location filter (≤50 km): 2019
# After location (≤50 km): 2019
# After age rule: 1679
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1890
# Unfiltered: 1890 | After location filter (≤50 km): 1864
# After location (≤50 km): 1864
# After age rule: 587
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2038
# Unfiltered: 2038 | After location filter (≤50 km): 2029
# After location (≤50 km): 2029
# After age rule: 1685
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2609
# Unfiltered: 2609 | After location filter (≤50 km): 2586
# After location (≤50 km): 2586
# After age rule: 2419
# Start pool: 5000 (max_candidates=5000)
# After orientation: 326
# Unfiltered: 326 | After location filter (≤50 km): 324
# After location (≤50 km): 324
# After age rule: 258
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2143
# Unfiltered: 2143 | After location filter (≤50 km): 2134
# After location (≤50 km): 2134
# After age rule: 1956
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2259
# Unfiltered: 2259 | After location filter (≤50 km): 2240
# After location (≤50 km): 2240
# After age rule: 1770
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2734
# Unfiltered: 2734 | After location filter (≤50 km): 2683
# After location (≤50 km): 2683
# After age rule: 2162
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1987
# Unfiltered: 1987 | After location filter (≤50 km): 1780
# After location (≤50 km): 1780
# After age rule: 708
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1941
# Unfiltered: 1941 | After location filter (≤50 km): 1924
# After location (≤50 km): 1924
# After age rule: 1642
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1991
# Unfiltered: 1991 | After location filter (≤50 km): 1972
# After location (≤50 km): 1972
# After age rule: 1556
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2089
# Unfiltered: 2089 | After location filter (≤50 km): 2078
# After location (≤50 km): 2078
# After age rule: 1021
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2876
# Unfiltered: 2876 | After location filter (≤50 km): 2771
# After location (≤50 km): 2771
# After age rule: 1280
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2019
# Unfiltered: 2019 | After location filter (≤50 km): 2009
# After location (≤50 km): 2009
# After age rule: 1587
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1728
# Unfiltered: 1728 | After location filter (≤50 km): 1711
# After location (≤50 km): 1711
# After age rule: 1027
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1936
# Unfiltered: 1936 | After location filter (≤50 km): 1916
# After location (≤50 km): 1916
# After age rule: 1587
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2134
# Unfiltered: 2134 | After location filter (≤50 km): 2126
# After location (≤50 km): 2126
# After age rule: 1751
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2557
# Unfiltered: 2557 | After location filter (≤50 km): 2552
# After location (≤50 km): 2552
# After age rule: 1150
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1966
# Unfiltered: 1966 | After location filter (≤50 km): 1948
# After location (≤50 km): 1948
# After age rule: 1566
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1902
# Unfiltered: 1902 | After location filter (≤50 km): 1895
# After location (≤50 km): 1895
# After age rule: 1475
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2028
# Unfiltered: 2028 | After location filter (≤50 km): 2015
# After location (≤50 km): 2015
# After age rule: 1280
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1920
# Unfiltered: 1920 | After location filter (≤50 km): 1906
# After location (≤50 km): 1906
# After age rule: 1642
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2360
# Unfiltered: 2360 | After location filter (≤50 km): 2354
# After location (≤50 km): 2354
# After age rule: 1563
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1709
# Unfiltered: 1709 | After location filter (≤50 km): 1699
# After location (≤50 km): 1699
# After age rule: 1098
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2435
# Unfiltered: 2435 | After location filter (≤50 km): 2423
# After location (≤50 km): 2423
# After age rule: 2005
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2020
# Unfiltered: 2020 | After location filter (≤50 km): 2009
# After location (≤50 km): 2009
# After age rule: 1387
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1703
# Unfiltered: 1703 | After location filter (≤50 km): 1697
# After location (≤50 km): 1697
# After age rule: 1489
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1637
# Unfiltered: 1637 | After location filter (≤50 km): 1630
# After location (≤50 km): 1630
# After age rule: 1462
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2106
# Unfiltered: 2106 | After location filter (≤50 km): 2098
# After location (≤50 km): 2098
# After age rule: 1676
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2182
# Unfiltered: 2182 | After location filter (≤50 km): 2159
# After location (≤50 km): 2159
# After age rule: 1928
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1989
# Unfiltered: 1989 | After location filter (≤50 km): 1883
# After location (≤50 km): 1883
# After age rule: 1471
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1875
# Unfiltered: 1875 | After location filter (≤50 km): 1863
# After location (≤50 km): 1863
# After age rule: 791
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2391
# Unfiltered: 2391 | After location filter (≤50 km): 2378
# After location (≤50 km): 2378
# After age rule: 1796
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2151
# Unfiltered: 2151 | After location filter (≤50 km): 2136
# After location (≤50 km): 2136
# After age rule: 1764
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1837
# Unfiltered: 1837 | After location filter (≤50 km): 1826
# After location (≤50 km): 1826
# After age rule: 1597
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2077
# Unfiltered: 2077 | After location filter (≤50 km): 2074
# After location (≤50 km): 2074
# After age rule: 1511
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2329
# Unfiltered: 2329 | After location filter (≤50 km): 2321
# After location (≤50 km): 2321
# After age rule: 2031
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1695
# Unfiltered: 1695 | After location filter (≤50 km): 1516
# After location (≤50 km): 1516
# After age rule: 792
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2529
# Unfiltered: 2529 | After location filter (≤50 km): 2314
# After location (≤50 km): 2314
# After age rule: 2005
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2208
# Unfiltered: 2208 | After location filter (≤50 km): 2206
# After location (≤50 km): 2206
# After age rule: 1587
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2099
# Unfiltered: 2099 | After location filter (≤50 km): 1939
# After location (≤50 km): 1939
# After age rule: 1132
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2633
# Unfiltered: 2633 | After location filter (≤50 km): 2607
# After location (≤50 km): 2607
# After age rule: 2035
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1731
# Unfiltered: 1731 | After location filter (≤50 km): 1721
# After location (≤50 km): 1721
# After age rule: 1514
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2257
# Unfiltered: 2257 | After location filter (≤50 km): 2236
# After location (≤50 km): 2236
# After age rule: 1298
# Start pool: 5000 (max_candidates=5000)
# After orientation: 489
# Unfiltered: 489 | After location filter (≤50 km): 487
# After location (≤50 km): 487
# After age rule: 434
# Start pool: 5000 (max_candidates=5000)
# After orientation: 452
# Unfiltered: 452 | After location filter (≤50 km): 417
# After location (≤50 km): 417
# After age rule: 351
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2164
# Unfiltered: 2164 | After location filter (≤50 km): 2139
# After location (≤50 km): 2139
# After age rule: 1619
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1844
# Unfiltered: 1844 | After location filter (≤50 km): 1760
# After location (≤50 km): 1760
# After age rule: 1135
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2345
# Unfiltered: 2345 | After location filter (≤50 km): 2328
# After location (≤50 km): 2328
# After age rule: 1284
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2191
# Unfiltered: 2191 | After location filter (≤50 km): 2173
# After location (≤50 km): 2173
# After age rule: 1896
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1747
# Unfiltered: 1747 | After location filter (≤50 km): 1738
# After location (≤50 km): 1738
# After age rule: 1551
# Start pool: 5000 (max_candidates=5000)
# After orientation: 230
# Unfiltered: 230 | After location filter (≤50 km): 229
# After location (≤50 km): 229
# After age rule: 159
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2582
# Unfiltered: 2582 | After location filter (≤50 km): 2244
# After location (≤50 km): 2244
# After age rule: 1583
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2004
# Unfiltered: 2004 | After location filter (≤50 km): 2002
# After location (≤50 km): 2002
# After age rule: 643
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1979
# Unfiltered: 1979 | After location filter (≤50 km): 1973
# After location (≤50 km): 1973
# After age rule: 1500
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1992
# Unfiltered: 1992 | After location filter (≤50 km): 1985
# After location (≤50 km): 1985
# After age rule: 1625
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2429
# Unfiltered: 2429 | After location filter (≤50 km): 2401
# After location (≤50 km): 2401
# After age rule: 2281
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1764
# Unfiltered: 1764 | After location filter (≤50 km): 1755
# After location (≤50 km): 1755
# After age rule: 1463
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1888
# Unfiltered: 1888 | After location filter (≤50 km): 1882
# After location (≤50 km): 1882
# After age rule: 1658
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2055
# Unfiltered: 2055 | After location filter (≤50 km): 2053
# After location (≤50 km): 2053
# After age rule: 1746
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1756
# Unfiltered: 1756 | After location filter (≤50 km): 1742
# After location (≤50 km): 1742
# After age rule: 1248
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2082
# Unfiltered: 2082 | After location filter (≤50 km): 1949
# After location (≤50 km): 1949
# After age rule: 1651
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2159
# Unfiltered: 2159 | After location filter (≤50 km): 1964
# After location (≤50 km): 1964
# After age rule: 1647
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2279
# Unfiltered: 2279 | After location filter (≤50 km): 2261
# After location (≤50 km): 2261
# After age rule: 1810
# Start pool: 5000 (max_candidates=5000)
# After orientation: 397
# Unfiltered: 397 | After location filter (≤50 km): 395
# After location (≤50 km): 395
# After age rule: 345
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2838
# Unfiltered: 2838 | After location filter (≤50 km): 2810
# After location (≤50 km): 2810
# After age rule: 2194
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2589
# Unfiltered: 2589 | After location filter (≤50 km): 2317
# After location (≤50 km): 2317
# After age rule: 1202
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1924
# Unfiltered: 1924 | After location filter (≤50 km): 1921
# After location (≤50 km): 1921
# After age rule: 480
# Start pool: 5000 (max_candidates=5000)
# After orientation: 451
# Unfiltered: 451 | After location filter (≤50 km): 447
# After location (≤50 km): 447
# After age rule: 265
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2419
# Unfiltered: 2419 | After location filter (≤50 km): 2414
# After location (≤50 km): 2414
# After age rule: 1166
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1874
# Unfiltered: 1874 | After location filter (≤50 km): 1870
# After location (≤50 km): 1870
# After age rule: 1510
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1950
# Unfiltered: 1950 | After location filter (≤50 km): 1931
# After location (≤50 km): 1931
# After age rule: 627
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1971
# Unfiltered: 1971 | After location filter (≤50 km): 1964
# After location (≤50 km): 1964
# After age rule: 1720
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1787
# Unfiltered: 1787 | After location filter (≤50 km): 1548
# After location (≤50 km): 1548
# After age rule: 1258
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1882
# Unfiltered: 1882 | After location filter (≤50 km): 1820
# After location (≤50 km): 1820
# After age rule: 969
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2190
# Unfiltered: 2190 | After location filter (≤50 km): 2034
# After location (≤50 km): 2034
# After age rule: 1290
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2403
# Unfiltered: 2403 | After location filter (≤50 km): 2363
# After location (≤50 km): 2363
# After age rule: 2048
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2168
# Unfiltered: 2168 | After location filter (≤50 km): 2165
# After location (≤50 km): 2165
# After age rule: 1237
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2271
# Unfiltered: 2271 | After location filter (≤50 km): 2069
# After location (≤50 km): 2069
# After age rule: 1431
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1395
# Unfiltered: 1395 | After location filter (≤50 km): 1375
# After location (≤50 km): 1375
# After age rule: 1191
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2255
# Unfiltered: 2255 | After location filter (≤50 km): 2242
# After location (≤50 km): 2242
# After age rule: 1891
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1605
# Unfiltered: 1605 | After location filter (≤50 km): 1450
# After location (≤50 km): 1450
# After age rule: 538
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1948
# Unfiltered: 1948 | After location filter (≤50 km): 1806
# After location (≤50 km): 1806
# After age rule: 1513
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2308
# Unfiltered: 2308 | After location filter (≤50 km): 2283
# After location (≤50 km): 2283
# After age rule: 2081
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1734
# Unfiltered: 1734 | After location filter (≤50 km): 1719
# After location (≤50 km): 1719
# After age rule: 1329
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1945
# Unfiltered: 1945 | After location filter (≤50 km): 1808
# After location (≤50 km): 1808
# After age rule: 1262
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1615
# Unfiltered: 1615 | After location filter (≤50 km): 1615
# After location (≤50 km): 1615
# After age rule: 1450
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2490
# Unfiltered: 2490 | After location filter (≤50 km): 2473
# After location (≤50 km): 2473
# After age rule: 2226
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1955
# Unfiltered: 1955 | After location filter (≤50 km): 1788
# After location (≤50 km): 1788
# After age rule: 1301
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2839
# Unfiltered: 2839 | After location filter (≤50 km): 2836
# After location (≤50 km): 2836
# After age rule: 1925
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2359
# Unfiltered: 2359 | After location filter (≤50 km): 2116
# After location (≤50 km): 2116
# After age rule: 1753
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2495
# Unfiltered: 2495 | After location filter (≤50 km): 2487
# After location (≤50 km): 2487
# After age rule: 1756
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2003
# Unfiltered: 2003 | After location filter (≤50 km): 1978
# After location (≤50 km): 1978
# After age rule: 1523
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2399
# Unfiltered: 2399 | After location filter (≤50 km): 2360
# After location (≤50 km): 2360
# After age rule: 2161
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2112
# Unfiltered: 2112 | After location filter (≤50 km): 2103
# After location (≤50 km): 2103
# After age rule: 1849
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2050
# Unfiltered: 2050 | After location filter (≤50 km): 2033
# After location (≤50 km): 2033
# After age rule: 1816
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2501
# Unfiltered: 2501 | After location filter (≤50 km): 2331
# After location (≤50 km): 2331
# After age rule: 666
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2578
# Unfiltered: 2578 | After location filter (≤50 km): 2535
# After location (≤50 km): 2535
# After age rule: 1690
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1971
# Unfiltered: 1971 | After location filter (≤50 km): 1963
# After location (≤50 km): 1963
# After age rule: 1797
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2709
# Unfiltered: 2709 | After location filter (≤50 km): 2422
# After location (≤50 km): 2422
# After age rule: 474
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1876
# Unfiltered: 1876 | After location filter (≤50 km): 1871
# After location (≤50 km): 1871
# After age rule: 1562
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1706
# Unfiltered: 1706 | After location filter (≤50 km): 1700
# After location (≤50 km): 1700
# After age rule: 973
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2099
# Unfiltered: 2099 | After location filter (≤50 km): 1807
# After location (≤50 km): 1807
# After age rule: 1523
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1904
# Unfiltered: 1904 | After location filter (≤50 km): 1891
# After location (≤50 km): 1891
# After age rule: 1407
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2006
# Unfiltered: 2006 | After location filter (≤50 km): 1771
# After location (≤50 km): 1771
# After age rule: 1159
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2090
# Unfiltered: 2090 | After location filter (≤50 km): 2067
# After location (≤50 km): 2067
# After age rule: 1692
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1748
# Unfiltered: 1748 | After location filter (≤50 km): 1729
# After location (≤50 km): 1729
# After age rule: 1436
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2781
# Unfiltered: 2781 | After location filter (≤50 km): 2771
# After location (≤50 km): 2771
# After age rule: 2526
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2309
# Unfiltered: 2309 | After location filter (≤50 km): 2286
# After location (≤50 km): 2286
# After age rule: 1900
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2599
# Unfiltered: 2599 | After location filter (≤50 km): 2574
# After location (≤50 km): 2574
# After age rule: 2408
# AUC-ROC: 0.952 ± 0.008 | PR-AUC: 0.992 ± 0.004
#                  coef (standardized)
# text_sim                    3.135953
# lifestyle_score             1.671583
# essay_len                   0.145017
# dist_penalty                0.000000
# age_diff                   -0.049669
#                  coef (standardized)
# age_diff                   -0.049669
# dist_penalty                0.000000
# essay_len                   0.145017
# lifestyle_score             1.671583
# text_sim                    3.135953

# %%
"""
text_sim = +3.14 → by far the strongest signal. 
Higher text similarity sharply increases the mutual-like probability.

lifestyle_score = +1.67 → solid positive effect. Matching lifestyle helps meaningfully.

essay_len = +0.15 → tiny positive: longer/more complete bios help a bit.

age_diff = −0.05 → very small negative: being further apart in age slightly hurts.

dist_penalty = 0.00 → effectively ignored 
Likely all/most training pairs had dist_penalty = 0 (inside 50 km), 
so the model learned no within-radius distance preference.

"""

# %%
def hinge_prob(user_id, k=20, model=hinge_model, pool_k=800, max_km=50):
    """Build a pool, make the SAME features used in training, predict, return top-k."""
    # 1) pool (orientation/location/age hard; lifestyle soft)
    pool = build_pool(user_id=user_id, pool_k=pool_k, max_km=max_km).copy()

    # 2) features in EXACT order the model expects
    X = pool[model["X_cols"]].copy()

    # 3) same cleaning as training
    if "dist_penalty" not in X.columns and "distance_km" in pool.columns:
        X["dist_penalty"] = np.maximum(0.0, pool["distance_km"] - max_km)
    X["essay_len"]    = X["essay_len"].fillna(0).clip(lower=0)
    X["dist_penalty"] = X["dist_penalty"].fillna(0).clip(lower=0)

    # 4) scale + predict
    X_scaled = model["scaler"].transform(X)
    p = model["clf"].predict_proba(X_scaled)[:, 1]

    # 5) attach predictions
    out = pool.copy()
    out["prob_mutual_like"] = p

    # 6) human-readable breakdown (uses flat-inside-radius rule)
    def _explain(r):
        dist = r.get("distance_km", np.nan)
        dist_txt = "?" if pd.isna(dist) else int(round(dist))
        pen = r.get("dist_penalty", 0.0)
        loc_score = 1.0 if pen <= 0 else max(0.0, 1.0 - min(1.0, pen / max_km))
        return (f"text={r.text_sim:.2f}, life={r.lifestyle_score:.2f}, "
                f"age={int(r.age_score)}, loc={loc_score:.2f}, "
                f"Δage={int(r.age_diff)}, dist~{dist_txt}km")

    out["feature_breakdown"] = out.apply(_explain, axis=1)

    # 7) tidy columns & return top-k
    cols = ["user_id","prob_mutual_like","feature_breakdown",
            "text_sim","lifestyle_score","age_score",
            "dist_penalty","distance_km","age","sex","orientation","location"]
    for c in cols:
        if c not in out.columns:
            out[c] = np.nan
    return out.sort_values("prob_mutual_like", ascending=False).head(k).reset_index(drop=True)

# %%
hinge_top = hinge_prob(user_id=12, k=10, model=hinge_model, pool_k=800, max_km=50)
hinge_top
# Out:
# Start pool: 5000 (max_candidates=5000)
# After orientation: 1561
# Unfiltered: 1561 | After location filter (≤50 km): 1552
# After location (≤50 km): 1552
# After age rule: 1081
#    user_id   age sex orientation                   location  text_sim  \
# 0    27365  24.0   f    straight  san francisco, california  0.596096
# 1     2695  21.0   f    bisexual         novato, california  0.592071
# 2    15562  21.0   f    straight       berkeley, california  0.591714
# 3    58866  22.0   f    straight      san mateo, california  0.591408
# 4    51829  30.0   f    straight  san francisco, california  0.586222
# 5    49159  24.0   f    straight  san francisco, california  0.583664
# 6    48293  24.0   f    straight  san francisco, california  0.583664
# 7    40249  24.0   f    straight  san francisco, california  0.583664
# 8    32359  24.0   f    straight      san bruno, california  0.583664
# 9    42193  24.0   f    straight        oakland, california  0.583664
#
#    age_score  age_diff  lifestyle_score  loc_score  dist_penalty  distance_km  \
# 0        1.0         0              1.0        1.0           0.0     0.000000
# 1        1.0         3              1.0        1.0           0.0    38.624527
# 2        1.0         3              1.0        1.0           0.0    16.407002
# 3        1.0         2              1.0        1.0           0.0    32.302391
# 4        1.0         6              1.0        1.0           0.0     0.000000
# 5        1.0         0              1.0        1.0           0.0     0.000000
# 6        1.0         0              1.0        1.0           0.0     0.000000
# 7        1.0         0              1.0        1.0           0.0     0.000000
# 8        1.0         0              1.0        1.0           0.0    17.174141
# 9        1.0         0              1.0        1.0           0.0    13.300941
#
#    essay_len  prob_mutual_like  \
# 0         59          0.845938
# 1         69          0.812392
# 2         55          0.809331
# 3         54          0.808480
# 4         72          0.756461
# 5         45          0.742836
# 6         45          0.742834
# 7         45          0.742834
# 8         45          0.742834
# 9         45          0.742834
#
#                                    feature_breakdown
# 0  text=0.60, life=1.00, age=1, loc=1.00, Δage=0,...
# 1  text=0.59, life=1.00, age=1, loc=1.00, Δage=3,...
# 2  text=0.59, life=1.00, age=1, loc=1.00, Δage=3,...
# 3  text=0.59, life=1.00, age=1, loc=1.00, Δage=2,...
# 4  text=0.59, life=1.00, age=1, loc=1.00, Δage=6,...
# 5  text=0.58, life=1.00, age=1, loc=1.00, Δage=0,...
# 6  text=0.58, life=1.00, age=1, loc=1.00, Δage=0,...
# 7  text=0.58, life=1.00, age=1, loc=1.00, Δage=0,...
# 8  text=0.58, life=1.00, age=1, loc=1.00, Δage=0,...
# 9  text=0.58, life=1.00, age=1, loc=1.00, Δage=0,...

# %%
#with build_pool settings: drinks_strict=False, smokes_strict=True, drugs_strict=True
hinge = hinge_prob(user_id=15, k=100, model=hinge_model, pool_k=500, max_km=45)
hinge
# Out:
# Start pool: 5000 (max_candidates=5000)
# After orientation: 2005
# Unfiltered: 2005 | After location filter (≤45 km): 1941
# After location (≤45 km): 1941
# After age rule: 1478
#     user_id   age sex orientation                   location  text_sim  \
# 0     28566  30.0   m    straight  san francisco, california  0.682167
# 1     49783  42.0   m    straight        oakland, california  0.681057
# 2     58244  48.0   m    straight         moraga, california  0.672608
# 3     20973  43.0   m    straight      san mateo, california  0.665855
# 4     33449  50.0   m    straight  san francisco, california  0.665802
# ..      ...   ...  ..         ...                        ...       ...
# 95    11758  30.0   m    straight     el cerrito, california  0.608280
# 96    21076  35.0   m    straight        hayward, california  0.610922
# 97    56383  29.0   m    straight        vallejo, california  0.608997
# 98    20893  40.0   m    straight  san francisco, california  0.592386
# 99    16504  37.0   m    straight  san francisco, california  0.604052
#
#     age_score  age_diff  lifestyle_score  loc_score  dist_penalty  \
# 0         1.0         9              1.0        1.0           0.0
# 1         1.0         3              1.0        1.0           0.0
# 2         1.0         9              1.0        1.0           0.0
# 3         1.0         4              1.0        1.0           0.0
# 4         1.0        11              1.0        1.0           0.0
# ..        ...       ...              ...        ...           ...
# 95        1.0         9              1.0        1.0           0.0
# 96        1.0         4              1.0        1.0           0.0
# 97        1.0        10              1.0        1.0           0.0
# 98        1.0         1              1.0        1.0           0.0
# 99        1.0         2              1.0        1.0           0.0
#
#     distance_km  essay_len  prob_mutual_like  \
# 0      0.000000       1740          0.998035
# 1     13.300941       1062          0.997894
# 2     26.260308       2489          0.997040
# 3     32.302391        713          0.995174
# 4      0.000000        953          0.994933
# ..          ...        ...               ...
# 95    18.340803       2751          0.926389
# 96    32.207482        782          0.924489
# 97    38.834789       2226          0.924257
# 98     0.000000       9045          0.923098
# 99     0.000000       3643          0.923068
#
#                                     feature_breakdown
# 0   text=0.68, life=1.00, age=1, loc=1.00, Δage=9,...
# 1   text=0.68, life=1.00, age=1, loc=1.00, Δage=3,...
# 2   text=0.67, life=1.00, age=1, loc=1.00, Δage=9,...
# 3   text=0.67, life=1.00, age=1, loc=1.00, Δage=4,...
# 4   text=0.67, life=1.00, age=1, loc=1.00, Δage=11...
# ..                                                ...
# 95  text=0.61, life=1.00, age=1, loc=1.00, Δage=9,...
# 96  text=0.61, life=1.00, age=1, loc=1.00, Δage=4,...
# 97  text=0.61, life=1.00, age=1, loc=1.00, Δage=10...
# 98  text=0.59, life=1.00, age=1, loc=1.00, Δage=1,...
# 99  text=0.60, life=1.00, age=1, loc=1.00, Δage=2,...
#
# [100 rows x 15 columns]

# %%
import pandas as pd, json, os
from datetime import datetime

# ensure folder
os.makedirs("results", exist_ok=True)

# standardize + annotate
hinge = hinge.reset_index(drop=True).copy()
hinge["rank"] = range(1, len(hinge) + 1)
hinge["app"]  = "hinge"

# metadata relevant to hinge
meta = {
    "app": "hinge",
    "user_id": 15,
    "top_n": 100,
    "pool_k": 500,
    "max_km": 45,
    # record model + pool filter context (optional but useful)
    "model": str(type(hinge_model.get("clf", hinge_model)).__name__) if isinstance(hinge_model, dict) else str(type(hinge_model).__name__),
    "pool_filters": {"drinks_strict": False, "smokes_strict": True, "drugs_strict": True},
    "timestamp": datetime.utcnow().isoformat() + "Z",
}

stem = f"results/hinge_user_id:{meta['user_id']}_k{meta['top_n']}_pool{meta['pool_k']}_km{meta['max_km']}"

# save
hinge.to_parquet(f"{stem}.parquet", index=False)
with open(f"{stem}.json", "w") as f:
    json.dump(meta, f, indent=2)

print("Saved:", f"{stem}.parquet and {stem}.json")
# Out:
# Saved: results/hinge_user_id:15_k100_pool500_km45.parquet and results/hinge_user_id:15_k100_pool500_km45.json
